# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Data analysis\indian_summer_beauty_products.csv')

# %%
df.shape
# Out:
# (10000, 20)

# %%
df.head(20)
# Out:
#    Product_ID Product_Name   Category       Brand  Average_Price  SPF_Rating  \
# 0      P00001    Sunscreen   Bodycare       Ponds         439.70          15
# 1      P00002     Lip Balm   Bodycare        Dove         178.55          30
# 2      P00003     Lip Balm   Skincare       Ponds         600.27          50
# 3      P00004  Body Lotion   Skincare     L'Oréal         749.37           0
# 4      P00005        Toner     Makeup    Biotique        1331.89          30
# 5      P00006      Shampoo     Makeup  Neutrogena        1132.57          30
# 6      P00007     Lip Balm   Skincare     Garnier        1466.04          30
# 7      P00008    Sunscreen   Skincare    Biotique         605.23          30
# 8      P00009  Moisturizer   Bodycare        Dove          57.07          30
# 9      P00010        Serum   Bodycare    Himalaya         717.79          30
# 10     P00011  Body Lotion   Bodycare        Dove        1427.91          30
# ...

# %%
df = df.drop('Hair_Type', axis=1)
print(df)
# Out:
#      Product_ID Product_Name  Category      Brand  Average_Price  SPF_Rating  \
# 0        P00001    Sunscreen  Bodycare      Ponds         439.70          15
# 1        P00002     Lip Balm  Bodycare       Dove         178.55          30
# 2        P00003     Lip Balm  Skincare      Ponds         600.27          50
# 3        P00004  Body Lotion  Skincare    L'Oréal         749.37           0
# 4        P00005        Toner    Makeup   Biotique        1331.89          30
# ...         ...          ...       ...        ...            ...         ...
# 9995     P09996      Shampoo  Bodycare      Nivea         396.54          50
# 9996     P09997      Shampoo  Bodycare   Himalaya        1286.66          15
# 9997     P09998    Face Wash  Skincare   Biotique        1075.28          15
# 9998     P09999  Conditioner  Skincare   Himalaya         787.11          15
# 9999     P10000    Face Wash  Skincare  Mamaearth         274.82           0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Product_ID              10000 non-null  object
#  1   Product_Name            10000 non-null  object
#  2   Category                10000 non-null  object
#  3   Brand                   10000 non-null  object
#  4   Average_Price           10000 non-null  float64
#  5   SPF_Rating              10000 non-null  int64
#  6   Skin_Type               10000 non-null  object
#  7   Age_Group               10000 non-null  object
#  8   Gender                  10000 non-null  object
#  9   Popularity_Rating       10000 non-null  int64
#  10  Usage_Frequency         10000 non-null  object
#  11  Primary_Ingredient      10000 non-null  object
#  12  Fragrance_Type          10000 non-null  object
#  13  Waterproof              10000 non-null  object
# ...

# %%
pd.isnull(df)
# Out:
#       Product_ID  Product_Name  Category  Brand  Average_Price  SPF_Rating  \
# 0          False         False     False  False          False       False
# 1          False         False     False  False          False       False
# 2          False         False     False  False          False       False
# 3          False         False     False  False          False       False
# 4          False         False     False  False          False       False
# ...          ...           ...       ...    ...            ...         ...
# 9995       False         False     False  False          False       False
# 9996       False         False     False  False          False       False
# 9997       False         False     False  False          False       False
# 9998       False         False     False  False          False       False
# 9999       False         False     False  False          False       False
#
# ...

# %%
pd.isnull(df).sum()
# Out:
# Product_ID                0
# Product_Name              0
# Category                  0
# Brand                     0
# Average_Price             0
# SPF_Rating                0
# Skin_Type                 0
# Age_Group                 0
# Gender                    0
# Popularity_Rating         0
# Usage_Frequency           0
# Primary_Ingredient        0
# Fragrance_Type            0
# Waterproof                0
# Organic                   0
# Paraben_Free              0
# Summer_Essential_Score    0
# Region_Usage              0
# Online_Availability       0
# dtype: int64

# %%
df.shape
# Out:
# (10000, 19)

# %%
df.describe()
# Out:
#        Average_Price    SPF_Rating  Popularity_Rating  Summer_Essential_Score
# count   10000.000000  10000.000000       10000.000000            10000.000000
# mean      774.110514     23.688500           3.035400                5.517200
# std       415.997772     18.489501           1.409591                2.867425
# min        50.110000      0.000000           1.000000                1.000000
# 25%       420.372500      0.000000           2.000000                3.000000
# 50%       773.525000     15.000000           3.000000                6.000000
# 75%      1129.337500     30.000000           4.000000                8.000000
# max      1499.920000     50.000000           5.000000               10.000000

# %%
df.columns
# Out:
# Index(['Product_ID', 'Product_Name', 'Category', 'Brand', 'Average_Price',
#        'SPF_Rating', 'Skin_Type', 'Age_Group', 'Gender', 'Popularity_Rating',
#        'Usage_Frequency', 'Primary_Ingredient', 'Fragrance_Type', 'Waterproof',
#        'Organic', 'Paraben_Free', 'Summer_Essential_Score', 'Region_Usage',
#        'Online_Availability'],
#       dtype='object')

# %%
# plotting a bar chart for Gender and it's count
ax = sns.countplot(x = 'Gender' ,data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.groupby(['Gender'], as_index=False)['Popularity_Rating'].sum().sort_values(by='Popularity_Rating', ascending=False)
# Out:
#    Gender  Popularity_Rating
# 2  Unisex              10505
# 1    Male              10063
# 0  Female               9786

# %%
# plotting a bar chart for Gender vs popularity_rate
choosen_method =df.groupby(['Gender'], as_index=False)['Popularity_Rating'].sum().sort_values(by='Popularity_Rating', ascending=False)
sns.barplot(x = 'Gender',y= 'Popularity_Rating' ,data = choosen_method)
# Out:
# <Axes: xlabel='Gender', ylabel='Popularity_Rating'>

# %%
#From the above graphs we can see most of the buyers are purchasing unisex productes according to the popularity_rating

# %%
ax = sns.countplot(data = df, x = 'Age_Group')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
#From above graph we can see the highest rate of buyer are of ADULT age group

# %%
sales_state = df.groupby(['Brand'], as_index=False)['SPF_Rating'].sum().sort_values(by='SPF_Rating', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'Brand',y= 'SPF_Rating')
# Out:
# <Axes: xlabel='Brand', ylabel='SPF_Rating'>

# %%
ax = sns.countplot(x = 'Brand' ,data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
#From above graph we can see that SPF_Rating is higher to ponds product compare to other products and purchasing rate is higher to himalaya

# %%
 ax = sns.countplot(x = 'Category' ,data = df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
Usage = df.groupby(['Category', 'Usage_Frequency'], as_index=False)['Average_Price'].sum().sort_values(by='Average_Price', ascending=False).head(10)

sns.set(rc={'figure.figsize':(16,8)})
sns.barplot(data = Usage, x = 'Category',y= 'Average_Price', hue= 'Usage_Frequency')
# Out:
# <Axes: xlabel='Category', ylabel='Average_Price'>

# %%
#From the above graph we can see skincare in daily is the most costly compare to other catogary and according to usage_frequency people is more care to bodycare

# %%
sales_state = df.groupby(['Brand'], as_index=False)['Average_Price'].sum().sort_values(by='Average_Price', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'Brand',y= 'Average_Price')
# Out:
# <Axes: xlabel='Brand', ylabel='Average_Price'>

# %%
#From the above graph we can understand himalaya brand is most earning company in the cosmetics field
